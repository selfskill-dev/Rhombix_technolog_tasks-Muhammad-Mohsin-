# %%
# Internship: Data Analysis
# Project 1 : Data Collection and Cleaning 
# Developer:  Muhammad Mohsin

# %%
# The first step is going on we are importing required libraries

import pandas as pd
import numpy as np

# %%
# Now we are loading or uploading our dataset which we are going to clean
df = pd.read_json("data_secinetis_job.json")

# Exploring dataSet
df.head()
# Out:
#         job_title seniority_level   status      company  \
# 0  data scientist          senior   hybrid  company_003
# 1  data scientist            lead   hybrid  company_005
# 2  data scientist          senior  on-site  company_007
# 3  data scientist          senior   hybrid  company_008
# 4  data scientist            None  on-site  company_009
#
#                                             location    post_date  \
# 0                             Grapevine, TX . Hybrid  17 days ago
# 1                            Fort Worth, TX . Hybrid  15 days ago
# 2  Austin, TX . Toronto, Ontario, Canada . Kirkla...  a month ago
# 3  Chicago, IL . Scottsdale, AZ . Austin, TX . Hy...   8 days ago
# 4                                            On-site   3 days ago
#
#             headquarter       industry ownership company_size  revenue  \
# 0   Bentonville, AR, US         Retail    Public     €352.44B   Public
# 1       Detroit, MI, US  Manufacturing    Public      155,030  €51.10B
# 2  Redwood City, CA, US     Technology    Public       25,930  €33.80B
# 3      San Jose, CA, US     Technology    Public       34,690  €81.71B
# 4      Stamford, CT, US        Finance   Private        1,800  Private
#
#                 salary                                             skills
# 0  €100,472 - €200,938  ['spark', 'r', 'python', 'scala', 'machine lea...
# 1             €118,733  ['spark', 'r', 'python', 'sql', 'machine learn...
# 2   €94,987 - €159,559  ['aws', 'git', 'python', 'docker', 'sql', 'mac...
# 3  €112,797 - €194,402                             ['sql', 'r', 'python']
# 4  €114,172 - €228,337                                                 []

# %%
# Now we are gaining information about the dataSet
print("\nInfo About DataSet")
df.info()
# Out:
# Info About DataSet
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 944 entries, 0 to 943
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   job_title        941 non-null    object
#  1   seniority_level  884 non-null    object
#  2   status           688 non-null    object
#  3   company          944 non-null    object
#  4   location         942 non-null    object
#  5   post_date        944 non-null    object
#  6   headquarter      944 non-null    object
#  7   industry         944 non-null    object
#  8   ownership        897 non-null    object
#  9   company_size     944 non-null    object
#  10  revenue          929 non-null    object
#  11  salary           944 non-null    object
#  12  skills           944 non-null    object
# dtypes: object(13)
# memory usage: 96.0+ KB

# %%
# Now we can check order like rows and column
print("rows,columns:",df.shape)
# Out:
# rows,columns: (944, 13)

# %%
df.describe(include='all')
# Out:
#              job_title seniority_level   status      company  \
# count              941             884      688          944
# unique               4               4        3          420
# top     data scientist          senior  on-site  company_134
# freq               856             630      363           30
#
#                            location    post_date            headquarter  \
# count                           942          944                    944
# unique                          431           42                    197
# top     Bengaluru, Karnataka, India  a month ago  San Francisco, CA, US
# freq                             52          167                     91
#
#           industry ownership company_size  revenue   salary skills
# count          944       897          944      929      944    944
# unique           8         2          510      312      896    400
# top     Technology    Public          900  Private  €25,214     []
# freq           582       579           18      247        3    201

# %%
#NOW start , Edit missing values

print("Missing values per row:",df.isnull().sum())
# Out:
# Missing values per row: job_title            3
# seniority_level     60
# status             256
# company              0
# location             2
# post_date            0
# headquarter          0
# industry             0
# ownership           47
# company_size         0
# revenue             15
# salary               0
# skills               0
# dtype: int64

# %%
# Now we can check duplication of data like rows and column
print("Duplicated rows:",df.duplicated().sum())
# Out:
# Duplicated rows: 0

# %%
# df.dropna()

# %%
# df.shape
# Out:
# (599, 13)

# %%
# df.duplicated().sum()

# It is not a valid possible solution because our too much data is to be lost so we replace missing values using fillna()
# Out:
# np.int64(0)

# %%
# 1. Check again to confirm missing values
df.isnull().sum()

# 2. Fill categorical columns with mode (most frequent value)
df['job_title'].fillna(df['job_title'].mode()[0], inplace=True)
df['seniority_level'].fillna(df['seniority_level'].mode()[0], inplace=True)
df['status'].fillna(df['status'].mode()[0], inplace=True)
df['location'].fillna(df['location'].mode()[0], inplace=True)
df['ownership'].fillna(df['ownership'].mode()[0], inplace=True)

# 3. Fill numeric or mixed columns with a suitable placeholder or mean if numeric
df['revenue'].fillna(df['revenue'].mode()[0], inplace=True)

# 4. Verify again if all missing values are handled
# print("Missing values per row after cleaning:")
print(df.isnull().sum())
# Out:
# job_title          0
# seniority_level    0
# status             0
# company            0
# location           0
# post_date          0
# headquarter        0
# industry           0
# ownership          0
# company_size       0
# revenue            0
# salary             0
# skills             0
# dtype: int64

# %%
# 1. Remove leading/trailing spaces (applymap → map fix)
for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = df[col].map(lambda x: x.strip() if isinstance(x, str) else x)

# 2. Convert text columns to lowercase
text_columns = ['job_title', 'seniority_level', 'status', 'company', 
                'location', 'headquarter', 'industry', 'ownership', 'skills']
for col in text_columns:
    df[col] = df[col].astype(str).str.lower()

# 3. Fix date format explicitly to avoid warning
df['post_date'] = pd.to_datetime(df['post_date'], format='%Y-%m-%d', errors='coerce')

# 4. Clean non-standard characters
df['company_size'] = df['company_size'].str.replace(r'[^0-9\-+]', '', regex=True)
df['revenue'] = df['revenue'].str.replace(r'[^0-9a-zA-Z\-\s]', '', regex=True)

# 5. Preview
df.head()
# Out:
#         job_title seniority_level   status      company  \
# 0  data scientist          senior   hybrid  company_003
# 1  data scientist            lead   hybrid  company_005
# 2  data scientist          senior  on-site  company_007
# 3  data scientist          senior   hybrid  company_008
# 4  data scientist          senior  on-site  company_009
#
#                                             location post_date  \
# 0                             grapevine, tx . hybrid       NaT
# 1                            fort worth, tx . hybrid       NaT
# 2  austin, tx . toronto, ontario, canada . kirkla...       NaT
# 3  chicago, il . scottsdale, az . austin, tx . hy...       NaT
# 4                                            on-site       NaT
#
#             headquarter       industry ownership company_size  revenue  \
# 0   bentonville, ar, us         retail    public        35244   Public
# 1       detroit, mi, us  manufacturing    public       155030    5110B
# 2  redwood city, ca, us     technology    public        25930    3380B
# 3      san jose, ca, us     technology    public        34690    8171B
# 4      stamford, ct, us        finance   private         1800  Private
#
#                 salary                                             skills
# 0  €100,472 - €200,938  ['spark', 'r', 'python', 'scala', 'machine lea...
# 1             €118,733  ['spark', 'r', 'python', 'sql', 'machine learn...
# 2   €94,987 - €159,559  ['aws', 'git', 'python', 'docker', 'sql', 'mac...
# 3  €112,797 - €194,402                             ['sql', 'r', 'python']
# 4  €114,172 - €228,337                                                 []

# %%
df
# Out:
#                      job_title seniority_level   status      company  \
# 0               data scientist          senior   hybrid  company_003
# 1               data scientist            lead   hybrid  company_005
# 2               data scientist          senior  on-site  company_007
# 3               data scientist          senior   hybrid  company_008
# 4               data scientist            None  on-site  company_009
# ..                         ...             ...      ...          ...
# 939             data scientist          senior     None  company_171
# 940  machine learning engineer          senior     None  company_134
# 941             data scientist        midlevel  on-site  company_395
# 942             data scientist        midlevel  on-site  company_395
# 943             data scientist          senior  on-site  company_844
#
#                                               location    post_date  \
# 0                               Grapevine, TX . Hybrid  17 days ago
# 1                              Fort Worth, TX . Hybrid  15 days ago
# 2    Austin, TX . Toronto, Ontario, Canada . Kirkla...  a month ago
# 3    Chicago, IL . Scottsdale, AZ . Austin, TX . Hy...   8 days ago
# 4                                              On-site   3 days ago
# ..                                                 ...          ...
# 939                        Bengaluru, Karnataka, India    a day ago
# 940                     Melbourne, Victoria, Australia  a month ago
# 941                                         McLean, VA  11 days ago
# 942                                       New York, NY  17 days ago
# 943                                      San Diego, CA   8 days ago
#
#                headquarter       industry ownership company_size   revenue  \
# 0      Bentonville, AR, US         Retail    Public     €352.44B    Public
# 1          Detroit, MI, US  Manufacturing    Public      155,030   €51.10B
# 2     Redwood City, CA, US     Technology    Public       25,930   €33.80B
# 3         San Jose, CA, US     Technology    Public       34,690   €81.71B
# 4         Stamford, CT, US        Finance   Private        1,800   Private
# ..                     ...            ...       ...          ...       ...
# 939         Armonk, NY, US     Technology    Public      524,598  €120.29B
# 940        Seattle, WA, US         Retail    Public      865,456  €838.78B
# 941         McLean, VA, US         Retail    Public       55,150   €36.29B
# 942         McLean, VA, US         Retail    Public       55,110   €36.34B
# 943  Mountain View, CA, US     Technology    Public       17,040   €95.22B
#
#                   salary                                             skills
# 0    €100,472 - €200,938  ['spark', 'r', 'python', 'scala', 'machine lea...
# 1               €118,733  ['spark', 'r', 'python', 'sql', 'machine learn...
# 2     €94,987 - €159,559  ['aws', 'git', 'python', 'docker', 'sql', 'mac...
# 3    €112,797 - €194,402                             ['sql', 'r', 'python']
# 4    €114,172 - €228,337                                                 []
# ..                   ...                                                ...
# 939    €33,288 - €53,080  ['pytorch', 'python', 'sql', 'machine learning...
# 940              €64,290                     ['amazon', 'machine learning']
# 941  €145,904 - €166,510  ['spark', 'aws', 'r', 'python', 'scala', 'sql'...
# 942  €159,149 - €181,595  ['spark', 'aws', 'r', 'python', 'scala', 'sql'...
# 943  €195,486 - €201,926  ['r', 'python', 'scala', 'sql', 'machine learn...
#
# [944 rows x 13 columns]

# %%
df.to_csv('cleaned_data.csv', index=False)
